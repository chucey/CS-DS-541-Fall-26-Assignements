# %% [markdown]
# # Problem 3 Solution

# %%
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
def gradient_descent(x_train, y_train, w0, alpha, num_steps):
  """
  Performs gradient descent to learn the weights of a linear regression model.

  Args:
    x_train (np.ndarray): The training input features.
    y_train (np.ndarray): The training target values.
    w0 (np.ndarray): The initial weights.
    alpha (float): The learning rate.
    num_steps (int): The number of gradient descent steps.

  Returns:
    np.ndarray: The learned weights.
  """
  # PRO TIP: CREATE DEEP COPY of arrays passed as args to avoid changing them
  # Your code here (~2 lines)
  x_train_copy = np.copy(x_train)
  y_train_copy = np.copy(y_train)
  w0 = np.copy(w0)

  losses = []

  for i in range(num_steps):

    # compute loss (~2 lines)
    # Your code here
    y_hat = np.dot(x_train_copy, w0)
    loss = np.mean((y_hat - y_train_copy) ** 2)
    losses.append(loss)
    
    # Placeholder for loss, remove after implementing
    # loss = 0 
    print(f'Training loss = {loss:.3f}')

    # compute gradients and update params (~2 lines)
    # Your code here
    gradient = (2 / x_train_copy.shape[0]) * np.dot(x_train_copy.T, (y_hat - y_train_copy))
    w0 -= alpha * gradient
    w = w0

  return w, losses


def train_linear_regression(x_train, y_train, alpha=0.01):
    """
    Initializes and trains a linear regression model.

    Args:
      x_train (np.ndarray): The training input features.
      y_train (np.ndarray): The training target values.

    Returns:
      np.ndarray: The trained model weights.
    """
    # PRO TIP: setting a random seed makes the experiments reproducible (hopefully in other systems too)
    np.random.seed(541)
    
    # Initialize weights (~2 lines)
    # Your code here 

    w0 = np.random.randn(x_train.shape[1])
    # b = np.random.randn(1)

    # Placeholder for w0, remove after implementing
    # w0 = np.zeros(x_train.shape[1])
    print(f'Model coefficients: {np.round(w0,3)}')

    # Make initial prediction (~1 line)
    # Your code here
    y_pred = np.dot(x_train, w0)

    # Placeholder for y_pred, remove after implementing
    # y_pred = np.zeros(y_train.shape)
    print(y_pred[:5])

    # Calculate initial loss (~1-2 lines)
    # PRO TIP: tracking the train loss at the beginning and during optimization is
    # key for debugging, determining convergence
    # Your code here
    loss = np.mean((y_pred - y_train) ** 2)

    # Placeholder for loss, remove after implementing
    # loss = 0
    print(f'Training loss = {loss:.3f}')

    # Run gradient descent
    w, losses = gradient_descent(x_train, y_train, w0, alpha, 100)

    return w, losses

def plot_loss_curves(x_train: np.ndarray, y_train: np.ndarray, alphas: list[float]):
    """
    Plots the loss curves for different learning rates.

    Args:
      alphas (list of float): The learning rates to evaluate.
    """
    plt.figure(figsize=(10, 6))
    for alpha in alphas:
        # Train model with the given alpha
        w, losses = train_linear_regression(x_train, y_train, alpha=alpha)
        plt.plot(losses, label=f'alpha={alpha}')
    
    plt.title('Loss Curves for Different Learning Rates')
    plt.xlabel('Iteration')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid()
    plt.show()
    plt.savefig('loss_curves.pdf')

def load_data():
    """
    Loads the training and testing data from .npy files.

    Returns:
      tuple: A tuple containing the training and testing data.
    """
    try:
        X_tr = np.reshape(np.load("age_regression/age_regression_Xtr.npy"), (-1, 48*48))
        ytr = np.load("age_regression/age_regression_ytr.npy")
        X_te = np.reshape(np.load("age_regression/age_regression_Xte.npy"), (-1, 48*48))
        yte = np.load("age_regression/age_regression_yte.npy")
        print(X_tr.shape, ytr.shape, X_te.shape, yte.shape)
    except FileNotFoundError:
        print("Dataset files not found. Please download them and place them in the same directory.")
        return
            
    return X_tr, ytr, X_te, yte

# %%
def main():
    """
    Main function to load data, pre-process, train, and evaluate the model.
    """
    # Load data from files
    # Make sure you have the .npy files in the same directory as this script
    X_tr, ytr, X_te, yte = load_data()

    # (optional) Pre-processing

    # PRO TIP: center and normalize the features from training set (~4 lines)
    # Your code here

    print("Normalizing the features...")
    # train_mean = np.mean(X_tr, axis=0)
    # train_std = np.std(X_tr, axis=0)
    # train_std[train_std == 0] = 1.0

    # X_tr = (X_tr - train_mean) / train_std
    # X_te = (X_te - train_mean) / train_std
    print("Feature normalization complete.")
    

    # PRO TIP: prepend a 1 to each of the observations in X_tr and X_te (~2 lines)
    # This way you can treat the bias just as a regular weight
    # Your code here
    print("Prepending a 1 to each observation in X_tr and X_te...")
    X_tr = np.hstack((np.ones((X_tr.shape[0], 1)), X_tr))
    X_te = np.hstack((np.ones((X_te.shape[0], 1)), X_te))
    print("Prepending complete.")
    print(f'X_tr shape after prepending: {X_tr.shape}, X_te shape after prepending: {X_te.shape}')

    # Train model
    print("Training the linear regression model...")
    w, losses = train_linear_regression(X_tr, ytr, alpha=2e-4)

    # Report fMSE cost on the training and testing data (separately)
    # Your code here (~4-6 lines)
    train_loss = np.mean((np.dot(X_tr, w) - ytr) ** 2)
    test_loss = np.mean((np.dot(X_te, w) - yte) ** 2)
    print(f'Training loss after training = {train_loss:.3f}')
    print(f'Testing loss after training = {test_loss:.3f}')
    # plot_loss_curves(X_tr, ytr, alphas=[1e-4, 2e-4, 5e-5])

main()
# Out:
# (5000, 2304) (5000,) (2500, 2304) (2500,)
# Normalizing the features...
# Feature normalization complete.
# Prepending a 1 to each observation in X_tr and X_te...
# Prepending complete.
# X_tr shape after prepending: (5000, 2305), X_te shape after prepending: (2500, 2305)
# Training the linear regression model...
# Model coefficients: [ 0.803  0.039  0.109 ...  0.882 -1.13  -0.027]
# [-36.12891776 -26.73343558 -29.29599607 -23.1388821  -25.61559408]
# Training loss = 5066.104
# Training loss = 5066.104
# Training loss = 2873.065
# Training loss = 1691.228
# Training loss = 1054.294
# Training loss = 710.991
# Training loss = 525.917
# Training loss = 426.108
# Training loss = 372.246
# Training loss = 343.144
# Training loss = 327.384
# Training loss = 318.815
# Training loss = 314.120
# Training loss = 311.515
# Training loss = 310.035
# Training loss = 309.163
# Training loss = 308.618
# Training loss = 308.250
# Training loss = 307.978
# Training loss = 307.758
# Training loss = 307.567
# Training loss = 307.391
# Training loss = 307.224
# Training loss = 307.063
# Training loss = 306.904
# Training loss = 306.748
# Training loss = 306.594
# Training loss = 306.440
# Training loss = 306.288
# Training loss = 306.137
# Training loss = 305.986
# Training loss = 305.837
# Training loss = 305.688
# Training loss = 305.540
# Training loss = 305.393
# Training loss = 305.247
# Training loss = 305.102
# Training loss = 304.957
# Training loss = 304.814
# Training loss = 304.671
# Training loss = 304.529
# Training loss = 304.388
# Training loss = 304.247
# Training loss = 304.107
# Training loss = 303.968
# Training loss = 303.830
# Training loss = 303.693
# Training loss = 303.556
# Training loss = 303.420
# Training loss = 303.285
# Training loss = 303.150
# Training loss = 303.016
# Training loss = 302.883
# Training loss = 302.751
# Training loss = 302.619
# Training loss = 302.488
# Training loss = 302.358
# Training loss = 302.228
# Training loss = 302.099
# Training loss = 301.971
# Training loss = 301.844
# Training loss = 301.717
# Training loss = 301.590
# Training loss = 301.465
# Training loss = 301.340
# Training loss = 301.216
# Training loss = 301.092
# Training loss = 300.969
# Training loss = 300.847
# Training loss = 300.725
# Training loss = 300.604
# Training loss = 300.483
# Training loss = 300.363
# Training loss = 300.244
# Training loss = 300.125
# Training loss = 300.007
# Training loss = 299.890
# Training loss = 299.773
# Training loss = 299.656
# Training loss = 299.541
# Training loss = 299.425
# Training loss = 299.311
# Training loss = 299.197
# Training loss = 299.083
# Training loss = 298.970
# Training loss = 298.858
# Training loss = 298.746
# Training loss = 298.635
# Training loss = 298.524
# Training loss = 298.414
# Training loss = 298.304
# Training loss = 298.195
# Training loss = 298.086
# Training loss = 297.978
# Training loss = 297.870
# Training loss = 297.763
# Training loss = 297.657
# Training loss = 297.551
# Training loss = 297.445
# Training loss = 297.340
# Training loss = 297.235
# Training loss after training = 297.131
# Testing loss after training = 312.245

# %%
X_tr, ytr, X_te, yte = load_data()
plot_loss_curves(X_tr, ytr, alphas=[6e-4, 2e-4, 1e-5])
# Out:
# (5000, 2304) (5000,) (2500, 2304) (2500,)
# Model coefficients: [ 0.803  0.039  0.109 ... -0.098  0.882 -1.13 ]
# [-33.81815081 -25.70298082 -32.41025507 -26.61713116 -21.19385922]
# Training loss = 5086.127
# Training loss = 5086.127
# Training loss = 510.231
# Training loss = 320.488
# Training loss = 312.175
# Training loss = 311.374
# Training loss = 310.892
# Training loss = 310.429
# Training loss = 309.975
# Training loss = 309.528
# Training loss = 309.088
# Training loss = 308.655
# Training loss = 308.229
# Training loss = 307.810
# Training loss = 307.397
# Training loss = 306.990
# Training loss = 306.590
# Training loss = 306.196
# Training loss = 305.808
# Training loss = 305.425
# Training loss = 305.048
# Training loss = 304.677
# Training loss = 304.311
# Training loss = 303.951
# Training loss = 303.595
# Training loss = 303.245
# Training loss = 302.900
# Training loss = 302.559
# Training loss = 302.224
# Training loss = 301.893
# Training loss = 301.566
# Training loss = 301.244
# Training loss = 300.927
# Training loss = 300.613
# Training loss = 300.304
# Training loss = 299.999
# Training loss = 299.698
# Training loss = 299.401
# Training loss = 299.108
# Training loss = 298.818
# Training loss = 298.532
# Training loss = 298.250
# Training loss = 297.972
# Training loss = 297.696
# Training loss = 297.425
# Training loss = 297.156
# Training loss = 296.891
# Training loss = 296.629
# Training loss = 296.370
# Training loss = 296.114
# Training loss = 295.861
# Training loss = 295.611
# Training loss = 295.364
# Training loss = 295.120
# Training loss = 294.879
# Training loss = 294.640
# Training loss = 294.404
# Training loss = 294.171
# Training loss = 293.940
# Training loss = 293.712
# Training loss = 293.486
# Training loss = 293.262
# Training loss = 293.041
# Training loss = 292.822
# Training loss = 292.606
# Training loss = 292.392
# Training loss = 292.180
# Training loss = 291.970
# Training loss = 291.762
# Training loss = 291.557
# Training loss = 291.353
# Training loss = 291.151
# Training loss = 290.952
# Training loss = 290.754
# Training loss = 290.558
# Training loss = 290.364
# Training loss = 290.172
# Training loss = 289.982
# Training loss = 289.793
# Training loss = 289.607
# Training loss = 289.421
# Training loss = 289.238
# Training loss = 289.056
# Training loss = 288.876
# Training loss = 288.697
# Training loss = 288.520
# Training loss = 288.345
# Training loss = 288.171
# Training loss = 287.998
# Training loss = 287.827
# Training loss = 287.657
# Training loss = 287.489
# Training loss = 287.322
# Training loss = 287.157
# Training loss = 286.993
# Training loss = 286.830
# Training loss = 286.668
# Training loss = 286.508
# Training loss = 286.349
# Training loss = 286.191
# Training loss = 286.034
# Model coefficients: [ 0.803  0.039  0.109 ... -0.098  0.882 -1.13 ]
# [-33.81815081 -25.70298082 -32.41025507 -26.61713116 -21.19385922]
# Training loss = 5086.127
# Training loss = 5086.127
# Training loss = 2887.747
# Training loss = 1701.799
# Training loss = 1061.986
# Training loss = 716.777
# Training loss = 530.485
# Training loss = 429.920
# Training loss = 375.597
# Training loss = 346.220
# Training loss = 330.300
# Training loss = 321.639
# Training loss = 316.895
# Training loss = 314.263
# Training loss = 312.772
# Training loss = 311.896
# Training loss = 311.352
# Training loss = 310.988
# Training loss = 310.722
# Training loss = 310.508
# Training loss = 310.323
# Training loss = 310.155
# Training loss = 309.995
# Training loss = 309.840
# Training loss = 309.689
# Training loss = 309.539
# Training loss = 309.391
# Training loss = 309.245
# Training loss = 309.099
# Training loss = 308.954
# Training loss = 308.810
# Training loss = 308.667
# Training loss = 308.524
# Training loss = 308.382
# Training loss = 308.241
# Training loss = 308.101
# Training loss = 307.962
# Training loss = 307.823
# Training loss = 307.685
# Training loss = 307.547
# Training loss = 307.411
# Training loss = 307.275
# Training loss = 307.139
# Training loss = 307.005
# Training loss = 306.871
# Training loss = 306.738
# Training loss = 306.605
# Training loss = 306.473
# Training loss = 306.342
# Training loss = 306.212
# Training loss = 306.082
# Training loss = 305.953
# Training loss = 305.824
# Training loss = 305.696
# Training loss = 305.569
# Training loss = 305.442
# Training loss = 305.316
# Training loss = 305.191
# Training loss = 305.066
# Training loss = 304.942
# Training loss = 304.818
# Training loss = 304.695
# Training loss = 304.573
# Training loss = 304.451
# Training loss = 304.330
# Training loss = 304.209
# Training loss = 304.089
# Training loss = 303.970
# Training loss = 303.851
# Training loss = 303.732
# Training loss = 303.615
# Training loss = 303.498
# Training loss = 303.381
# Training loss = 303.265
# Training loss = 303.149
# Training loss = 303.034
# Training loss = 302.920
# Training loss = 302.806
# Training loss = 302.693
# Training loss = 302.580
# Training loss = 302.468
# Training loss = 302.356
# Training loss = 302.245
# Training loss = 302.134
# Training loss = 302.024
# Training loss = 301.914
# Training loss = 301.805
# Training loss = 301.696
# Training loss = 301.588
# Training loss = 301.480
# Training loss = 301.373
# Training loss = 301.266
# Training loss = 301.160
# Training loss = 301.054
# Training loss = 300.949
# Training loss = 300.844
# Training loss = 300.740
# Training loss = 300.636
# Training loss = 300.532
# Training loss = 300.429
# Training loss = 300.327
# Model coefficients: [ 0.803  0.039  0.109 ... -0.098  0.882 -1.13 ]
# [-33.81815081 -25.70298082 -32.41025507 -26.61713116 -21.19385922]
# Training loss = 5086.127
# Training loss = 5086.127
# Training loss = 4960.222
# Training loss = 4837.639
# Training loss = 4718.288
# Training loss = 4602.086
# Training loss = 4488.948
# Training loss = 4378.794
# Training loss = 4271.546
# Training loss = 4167.127
# Training loss = 4065.462
# Training loss = 3966.478
# Training loss = 3870.105
# Training loss = 3776.274
# Training loss = 3684.918
# Training loss = 3595.971
# Training loss = 3509.370
# Training loss = 3425.054
# Training loss = 3342.961
# Training loss = 3263.034
# Training loss = 3185.214
# Training loss = 3109.447
# Training loss = 3035.679
# Training loss = 2963.856
# Training loss = 2893.927
# Training loss = 2825.843
# Training loss = 2759.555
# Training loss = 2695.014
# Training loss = 2632.176
# Training loss = 2570.996
# Training loss = 2511.429
# Training loss = 2453.432
# Training loss = 2396.966
# Training loss = 2341.989
# Training loss = 2288.461
# Training loss = 2236.346
# Training loss = 2185.605
# Training loss = 2136.202
# Training loss = 2088.102
# Training loss = 2041.271
# Training loss = 1995.674
# Training loss = 1951.281
# Training loss = 1908.058
# Training loss = 1865.974
# Training loss = 1825.001
# Training loss = 1785.109
# Training loss = 1746.268
# Training loss = 1708.452
# Training loss = 1671.633
# Training loss = 1635.785
# Training loss = 1600.882
# Training loss = 1566.900
# Training loss = 1533.814
# Training loss = 1501.600
# Training loss = 1470.236
# Training loss = 1439.699
# Training loss = 1409.968
# Training loss = 1381.020
# Training loss = 1352.836
# Training loss = 1325.395
# Training loss = 1298.678
# Training loss = 1272.665
# Training loss = 1247.338
# Training loss = 1222.679
# Training loss = 1198.670
# Training loss = 1175.294
# Training loss = 1152.535
# Training loss = 1130.376
# Training loss = 1108.801
# Training loss = 1087.795
# Training loss = 1067.343
# Training loss = 1047.430
# Training loss = 1028.042
# Training loss = 1009.165
# Training loss = 990.786
# Training loss = 972.892
# Training loss = 955.469
# Training loss = 938.506
# Training loss = 921.990
# Training loss = 905.910
# Training loss = 890.253
# Training loss = 875.009
# Training loss = 860.167
# Training loss = 845.717
# Training loss = 831.647
# Training loss = 817.948
# Training loss = 804.611
# Training loss = 791.624
# Training loss = 778.981
# Training loss = 766.670
# Training loss = 754.684
# Training loss = 743.015
# Training loss = 731.652
# Training loss = 720.589
# Training loss = 709.818
# Training loss = 699.331
# Training loss = 689.120
# Training loss = 679.178
# Training loss = 669.498
# Training loss = 660.074
# Training loss = 650.897
